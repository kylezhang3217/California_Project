# %%
import load_job

# %%
jobs = load_job.load_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-13b363d85104> in <module>
# ----> 1 jobs = load_job.load_data()
#
# AttributeError: module 'load_job' has no attribute 'load_data'

# %%
jobs = load_job.get_california_job_data()

# %%
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 11 columns):
# Area Type                     2900 non-null object
# Area Name                     2900 non-null object
# Period                        2900 non-null object
# Standard Occupational Code    2900 non-null int64
# Occupational Title            2900 non-null object
# Total Job Openings            2900 non-null int64
# Median Hourly Wage            2691 non-null float64
# Median Annual Wage            2851 non-null float64
# Entry Level Education         2900 non-null object
# Work Experience               2900 non-null object
# Job Training                  2900 non-null object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 249.3+ KB

# %%
import numpy as np

# %%
jobs_corrcoef = jobs.corrcoef()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b923c9f43d53> in <module>
# ----> 1 jobs_corrcoef = jobs.corrcoef()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'corrcoef'

# %%
jobs_corr = jobs.corr()

# %%
jobs_corr
# Out:
#                             Standard Occupational Code  Total Job Openings  \
# Standard Occupational Code                    1.000000           -0.010795
# Total Job Openings                           -0.010795            1.000000
# Median Hourly Wage                           -0.550761           -0.005401
# Median Annual Wage                           -0.557700           -0.008983
#
#                             Median Hourly Wage  Median Annual Wage
# Standard Occupational Code           -0.550761           -0.557700
# Total Job Openings                   -0.005401           -0.008983
# Median Hourly Wage                    1.000000            1.000000
# Median Annual Wage                    1.000000            1.000000

# %%
# %matplotlib inline # only in a Jupyter notebook
import matplotlib.pyplot as plt
jobs.hist(bins=50, figsize=(20,15))
plt.show()
# Out:
# UsageError: unrecognized arguments: # only in a Jupyter notebook

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
jobs.hist(bins=50, figsize=(20,15))
plt.show()

# %%
jobs
# Out:
#               Area Type                    Area Name     Period  \
# 0                County              Monterey County  2014-2024
# 1     Metropolitan Area                San Rafael MD  2014-2024
# 2     Metropolitan Area                    Chico MSA  2014-2024
# 3     Metropolitan Area                   Fresno MSA  2014-2024
# 4                County                 Marin County  2014-2024
# 5                County                Shasta County  2014-2024
# 6                County                Sonoma County  2014-2024
# 7                County                  Kern County  2014-2024
# 8                County                 Butte County  2014-2024
# 9                County                 Butte County  2014-2024
# 10    Metropolitan Area  Anaheim-Santa Ana-Irvine MD  2014-2024
# 11    Metropolitan Area  Anaheim-Santa Ana-Irvine MD  2014-2024
# 12    Metropolitan Area  Anaheim-Santa Ana-Irvine MD  2014-2024
# 13    Metropolitan Area  Anaheim-Santa Ana-Irvine MD  2014-2024
# ...

# %%
jobs[jobs["Area Name"].values]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f577587349d9> in <module>
# ----> 1 jobs[jobs["Area Name"].values]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
jobs[jobs["Area Name"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-8ec42be728c1> in <module>
# ----> 1 jobs[jobs["Area Name"]]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...

# %%
jobs["Area Name"].unique()
# Out:
# array(['Monterey County', 'San Rafael MD', 'Chico MSA', 'Fresno MSA',
#        'Marin County', 'Shasta County', 'Sonoma County', 'Kern County',
#        'Butte County', 'Anaheim-Santa Ana-Irvine MD', 'Bakersfield MSA',
#        'Stanislaus County', 'California', 'Ventura County',
#        'Eastern Sierra Region', 'Mother Lode Region',
#        'Hanford-Corcoran MSA', 'El Centro MSA', 'Imperial County',
#        'Fresno County', 'Kings County', 'Los Angeles County',
#        'Los Angeles-Long Beach-Glendale MD', 'Madera County',
#        'Madera MSA', 'Merced County', 'Merced MSA', 'Modesto MSA',
#        'Napa County', 'Orange County', 'Napa MSA', 'San Diego County',
#        'North Coast Region', 'North Valley Region',
#        'Northern Mountains Region', 'Oakland-Hayward-Berkeley MD',
#        'Oxnard-Thousand Oaks-Ventura MSA',
#        'San Jose-Sunnyvale-Santa Clara MSA', 'Redding MSA',
#        'San Joaquin County', 'Riverside-San Bernardino-Ontario MSA',
# ...

# %%
jobs[jobs["Area Name"] = "San Francisco-Redwood City-South San Francisco MD"]
# Out:
#   File "<ipython-input-15-5e75aff013f7>", line 1
#     jobs[jobs["Area Name"] = "San Francisco-Redwood City-South San Francisco MD"]
#                            ^
# SyntaxError: invalid syntax

# %%
jobs[jobs["Area Name"] == "San Francisco-Redwood City-South San Francisco MD"]
# Out:
#               Area Type                                          Area Name  \
# 1862  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1863  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1864  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1865  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1866  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1867  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1868  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1869  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1870  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1871  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1872  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# ...

# %%
jobs[jobs["Area Name"] == "San Francisco-Redwood City-South San Francisco MD"].sort_values(by="Median Annual Wage")
# Out:
#               Area Type                                          Area Name  \
# 1879  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1892  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1878  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1865  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1886  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1875  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1866  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1863  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1871  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1902  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# 1862  Metropolitan Area  San Francisco-Redwood City-South San Francisco MD
# ...

# %%
jobs[jobs["Area Name"] == "Oakland-Hayward-Berkeley MD"].sort_values(by="Median Annual Wage")
# Out:
#               Area Type                    Area Name     Period  \
# 1452  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1410  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1439  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1454  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1425  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1411  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1427  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1409  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1408  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1419  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1412  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1417  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1448  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# 1453  Metropolitan Area  Oakland-Hayward-Berkeley MD  2014-2024
# ...

# %%
jobs[jobs["Area Name"] == "San Jose-Sunnyvale-Santa Clara MSA"].sort_values(by="Median Annual Wage")
# Out:
#               Area Type                           Area Name     Period  \
# 1989  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1988  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1964  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1966  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1979  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1975  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1965  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1968  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1963  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1980  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1996  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# 1972  Metropolitan Area  San Jose-Sunnyvale-Santa Clara MSA  2014-2024
# ...

# %%
jobs[jobs["Area Name"] == "Kings County"].sort_values(by="Median Annual Wage")
# Out:
#     Area Type     Area Name     Period  Standard Occupational Code  \
# 613    County  Kings County  2014-2024                      353021
# 612    County  Kings County  2014-2024                      452092
# 649    County  Kings County  2014-2024                      352011
# 611    County  Kings County  2014-2024                      399021
# 653    County  Kings County  2014-2024                      359021
# 615    County  Kings County  2014-2024                      412011
# 629    County  Kings County  2014-2024                      372012
# 640    County  Kings County  2014-2024                      435081
# 616    County  Kings County  2014-2024                      412031
# 618    County  Kings County  2014-2024                      353031
# 641    County  Kings County  2014-2024                      452091
# 648    County  Kings County  2014-2024                      311014
# 626    County  Kings County  2014-2024                      537062
# ...

# %%
jobs[jobs["Area Name"] == "Los Angeles-Long Beach-Glendale MD"].sort_values(by="Median Annual Wage")
# Out:
#              Area Type                           Area Name     Period  \
# 759  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 739  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 711  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 731  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 727  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 713  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 736  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 733  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 710  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 741  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 723  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# 714  Metropolitan Area  Los Angeles-Long Beach-Glendale MD  2014-2024
# ...

# %%
jobs[jobs["Area Name"] == "Los Angeles County"].sort_values(by="Median Annual Wage")
# Out:
#     Area Type           Area Name     Period  Standard Occupational Code  \
# 708    County  Los Angeles County  2014-2024                      352011
# 689    County  Los Angeles County  2014-2024                      537064
# 661    County  Los Angeles County  2014-2024                      353021
# 681    County  Los Angeles County  2014-2024                      359021
# 677    County  Los Angeles County  2014-2024                      359011
# 663    County  Los Angeles County  2014-2024                      412011
# 686    County  Los Angeles County  2014-2024                      353022
# 683    County  Los Angeles County  2014-2024                      359031
# 660    County  Los Angeles County  2014-2024                      399021
# 691    County  Los Angeles County  2014-2024                      536021
# 673    County  Los Angeles County  2014-2024                      352021
# 664    County  Los Angeles County  2014-2024                      353031
# ...

# %%
jobs[jobs["Area Name"] == "California"].sort_values(by="Median Annual Wage")
# Out:
#     Area Type   Area Name     Period  Standard Occupational Code  \
# 166     State  California  2014-2024                      452092
# 192     State  California  2014-2024                      359031
# 160     State  California  2014-2024                      353021
# 180     State  California  2014-2024                      359011
# 188     State  California  2014-2024                      359021
# 200     State  California  2014-2024                      537064
# 162     State  California  2014-2024                      412011
# 186     State  California  2014-2024                      353022
# 175     State  California  2014-2024                      352021
# 159     State  California  2014-2024                      399021
# 161     State  California  2014-2024                      412031
# 163     State  California  2014-2024                      353031
# 185     State  California  2014-2024                      372012
# ...
